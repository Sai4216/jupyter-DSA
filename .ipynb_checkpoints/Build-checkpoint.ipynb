# %%
from collections import deque
que = deque()
que.append(5)
que.append(15)
que.append(55)

# %%
que.appendleft(48)
que
# Out:
# deque([48, 5, 15, 55])

# %%
from queue import Queue
q = Queue(maxsize = 2)
q.put(5)
q.put(4)
# q.put(6)
