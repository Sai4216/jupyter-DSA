# %%
res = ""
n = 13
while n > 0:
    if n%2 == 1:
        res += "1"
    else:
        res += "0"
    n = n//2
res = res[::-1]
res
# Out:
# '1101'

# %%
n = len(res)
num = 0
p1 = 1
for i in range(n-1,-1,-1):
    if res[i] == "1":
        num += p1
    p1 = p1*2
num
# Out:
# 13
