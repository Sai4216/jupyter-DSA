# %%
test1 = {
    'input' :  [5,7,6,9,2,5,5,4,2,2,2,2,488,3,1,86,4,3,8,1,58,6],
    'output' : [1, 1, 2, 2, 2, 2, 2, 3, 3, 4, 4, 5, 5, 5, 6, 6, 7, 8, 9, 58, 86, 488]
}
test2 = {
    'input' : [],
    'output' : []
}
test3 = {
    'input' : [2,2,2,2,2,2,2,2,2,2,2],
    'output' : [2,2,2,2,2,2,2,2,2,2,2]
}
test4 = {
    'input' : [16],
    'output' : [16]
}

# %%
tests = [test1 , test2 ,test3 ]

# %%
# Bubble sort

def Bubble_Sort(list):
    for i in range(len(list) - 1):
        for j in range(len(list) - 1 - i):
            if list[j] > list[j+1]:
                list[j] , list[j+1] = list[j+1] , list[j]
    return list

# %%
for test in tests: 
    print(Bubble_Sort(test['input']))
    print(Bubble_Sort(test['input']) == test['output'])
    # print(test)
# Out:
# [1, 1, 2, 2, 2, 2, 2, 3, 3, 4, 4, 5, 5, 5, 6, 6, 7, 8, 9, 58, 86, 488]
# True
# []
# True
# [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# True

# %%
#Merge sort
def merge(nums1,nums2):
    merge = []
    i = 0
    j = 0
    while i< len(nums1) and j < len(nums2):
        if nums1[i] < nums2[j]:
            merge.append(nums1[i])
            i += 1
        else:
            merge.append(nums2[j])
            j += 1
    nums1_tail = nums1[i:]
    nums2_tail = nums2[j:]
    return merge + nums1_tail + nums2_tail


def Merge_Sort(nums):
    if len(nums) <= 1:
        return nums
    mid = len(nums) // 2
    left = nums[:mid]
    right = nums[mid :]
    left_sorted , right_sorted = Merge_Sort(left) , Merge_Sor t(right)
    merged_list = merge(left_sorted , right_sorted)
    return merged_list

# %%
list = [2,5,4,3,6,8,4,5,3,6]
Merge_Sort(list)
# Out:
# [2, 3, 3, 4, 4, 5, 5, 6, 6, 8]

# %%
for test in tests:
    print(Bubble_Sort(test['input']) == test['output'])
# Out:
# True
# True
# True

# %%
#Quick sort

def partition(nums , start , end):
    l , r = start , end -1
    while l < r:
        if nums[l] <= nums[end]:
            l += 1
        elif nums[r]>nums[end]:
            r -= 1
        else:
            nums[l], nums[r] = nums[r],nums[l]
    if nums[l]>nums[end]:
        nums[l], nums[end] = nums[end],nums[l]   
        return l
    return end

def Quick_Sort(nums , start = 0, end = None):
    if end == None:
        end = len(nums) - 1
    if start < end:
        pivot = partition(nums , start , end)
        Quick_Sort(nums , start , pivot - 1)
        Quick_Sort(nums , pivot +1 , end)
    return nums

# %%
list = [2,5,4,3,6,8,4,5,3,6]
Quick_Sort(list)
# Out:
# [2, 3, 3, 4, 4, 5, 5, 6, 6, 8]

# %%
[2,4,6]==[4,6,2]
# Out:
# False

# %%
num = int(input('number :'))
num = str(num)
print(type(list(num)[1]))
# Out:
# number : 22
# <class 'str'>

# %%
list1 = [2,4,5,4,8,1,8,6]
i = 0
while True:
    print(list[i])
    i++
    list1 = list1[i:]
