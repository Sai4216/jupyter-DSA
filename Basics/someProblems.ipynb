# %%
list = [8,4,6,1,0,5,6,4]
target = 15
len(list)
# Out:
# 8

# %%
def index_sum(list , target):
    n = len(list)
    for i in range(n):
        for j in range(i,n+1):
            if sum(list[i:j]) == target:
                return i,j
    return None , None

# %%
index_sum(list,target)
# Out:
# (4, 8)

# %%
def sub_sequence(str,sub):
    list1 = list(sub)
    print('sub is :',list1)
    list2 = []
    str1 = str
    n1,n2=len(str),len(sub)
    m = 0
    for i in range(n1):
        i = i-m
        for j in range(n2):
            if str1[i]==sub[j] and str1[i] not in list2:
                list2.append(str[i])
                print(list2)
        m += 1
        str1 = str[i+m:]
        print(str1)
    return print('is subsequence',list1==list2)
sub_sequence('sai kumar','aia')
# Out:
# sub is : ['a', 'i', 'a']
# ai kumar
# ['s']
# ['s', 's']
# i kumar
# ['s', 's', 's']
#  kumar
# kumar
# umar
# mar
# ar
# ['s', 's', 's', 's']
# ['s', 's', 's', 's', 's']
# r
#
# is subsequence False

# %%
def sub_sequence():
    list = []
    def check(str,sub,i,j):
        if i==len(str) or j == len(sub):
            return True
        elif i == len(str):
            return 
        elif str[i] == sub[j]:
            return True
        elif j != len(sub):
            return check(str , sub,i,j+1)
        elif i != len(str):
            return check(str , sub,i+1,j)
        else:
            return check(str , sub,i+1,j)
    return check('sai kumar','aia',0,0)
sub_sequence()
# Out:
# True
