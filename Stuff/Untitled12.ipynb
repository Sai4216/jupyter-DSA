# %%
def find(arr,k):
    l = []
    for i in range(len(arr)):
        for j in range(i,len(arr)):
            if sum(arr[i:j+1])==k:
                l.append(arr[i:j+1])
    print(l)
find([3,4,-7,1,3,3,1,-4],7)
# Out:
# [[3, 4], [3, 4, -7, 1, 3, 3], [1, 3, 3], [3, 3, 1]]
