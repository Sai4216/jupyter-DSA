# %%
arr = [1 for _ in range(5)]
arr.count(1)
curr = arr[0]
pos = 0
c = 1
while arr.count(1) != 1:
    print(arr)
    # print(pos,c)
    pos = (pos + c )%5
    arr[pos] = 0
    pos = pos + c 
    if pos >= 5:
        c += 1
        # pos = pos%10
    print(pos)

print(arr)
# Out:
# [1, 1, 1, 1, 1]
# 2
# [1, 0, 1, 1, 1]
# 4
# [1, 0, 1, 0, 1]
# 1
# [0, 0, 1, 0, 1]
# 3
# [0, 0, 0, 0, 1]
